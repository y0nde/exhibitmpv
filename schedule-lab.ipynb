# %%
import pandas as pd

# %%
df = pd.read_csv("schedule.csv",header=None)

# %%
df.head()
# Out:
#                0      1      2
# 0  Tokyo500yesrs  10:00  10:18
# 1    004_shunbun  10:18  10:24
# 2     soundscape  10:24  10:40
# 3  Tokyo500yesrs  10:40  10:58
# 4    004_shunbun  10:58  11:04

# %%
start=[]
end=[]
for i,row in df.iterrows():
    tmp = row[1].split(":")
    x = (int(tmp[0])*60 + int(tmp[1])) * 60
    start.append(x)

for i,row in df.iterrows():
    tmp = row[2].split(":")
    x = (int(tmp[0])*60 + int(tmp[1])) * 60
    end.append(x)

# %%
df["start"]=start
df["end"]=end

# %%
dic = {"Tokyo500yesrs" : "./movie/Tokyo500.mp4",
       "004_shunbun" : "./movie/shunbun.mp4",
       "soundscape" : "./movie/AmazingVisual.mp4"
      }
time_dic = {"Tokyo500yesrs" : 1071,
       "004_shunbun" : 300,
       "soundscape" : 960
            
      }
path=[]
time=[]
for i, row in df.iterrows():
    path.append(dic[row[0]])
    time.append(time_dic[row[0]])
df[3] = time
df[0] = path

# %%
df
# Out:
#                             0      1      2  start    end     3
# 0        ./movie/Tokyo500.mp4  10:00  10:18  36000  37080  1071
# 1         ./movie/shunbun.mp4  10:18  10:24  37080  37440   300
# 2   ./movie/AmazingVisual.mp4  10:24  10:40  37440  38400   960
# 3        ./movie/Tokyo500.mp4  10:40  10:58  38400  39480  1071
# 4         ./movie/shunbun.mp4  10:58  11:04  39480  39840   300
# ..                        ...    ...    ...    ...    ...   ...
# 58        ./movie/shunbun.mp4  22:58  23:04  82680  83040   300
# 59  ./movie/AmazingVisual.mp4  23:04  23:20  83040  84000   960
# 60       ./movie/Tokyo500.mp4  23:20  23:38  84000  85080  1071
# 61        ./movie/shunbun.mp4  23:38  23:44  85080  85440   300
# 62  ./movie/AmazingVisual.mp4  23:44  24:00  85440  86400   960
#
# [63 rows x 6 columns]

# %%
df[[0,3,"start","end"]].to_csv("schedule.txt",sep=' ',header=None,index=None)
df.to_csv("schedule_with_time.txt",sep=' ',header=None,index=None)

# %%
import datetime

# %%
today = datetime.date.today()

# %%
from datetime import date
from datetime import datetime

dt = datetime.combine(date.today(), datetime.min.time())

# %%
dt.timestamp()
# Out:
# 1647788400.0

# %%
max_t = 23*60*60
x = 9*60*60
entry=[]
stream = []
begin = []
end = []
begin_s = []
end_s = []
today = datetime.combine(date.today(), datetime.min.time()).timestamp()
while(x < max_t):
    entry.extend(["./movie/Tokyo500.mp4","./movie/shunbun.mp4"])
    stream.extend([1071,300])
    begin.append(x)
    begin_s.append(datetime.fromtimestamp(today + x).strftime("%H:%M:%S"))
    x += 1071
    end.append(x+1)
    end_s.append(datetime.fromtimestamp(today + x + 1).strftime("%H:%M:%S"))
    begin.append(x)
    begin_s.append(datetime.fromtimestamp(today + x).strftime("%H:%M:%S"))
    x += 300
    end.append(x+1)
    end_s.append(datetime.fromtimestamp(today + x + 1).strftime("%H:%M:%S"))

# %%
pd.DataFrame({0:entry,1:stream,2:begin,3:end}).to_csv("tokyo500-shunbun.txt",sep=" ",index=None,header=None)
pd.DataFrame({0:entry,1:stream,2:begin_s,3:end_s}).to_csv("tokyo500-shunbun_with_time.txt",sep=" ",index=None,header=None)

#pd.DataFrame({0:entry,1:stream,2:begin,3:end}).to_csv("tokyo500-shunbun_test.txt",sep=" ",index=None,header=None)
#pd.DataFrame({0:entry,1:stream,3:begin_s,4:end_s}).to_csv("tokyo500-shunbun_test_with_time.txt",sep=" ",index=None,header=None)

# %%
max_t = 28*60*60
x = 15*60*60
entry=[]
stream = []
begin = []
end = []
begin_s = []
end_s = []
today = datetime.combine(date.today(), datetime.min.time()).timestamp()
while(x < max_t):
    entry.extend(["./movie/keichitsu.mp4","./movie/shunbun.mp4","./movie/seimei.mp4",
                  "./movie/kokuu.mp4","./movie/rikka.mp4"])
    stream.extend([300,300,300,300,300])
    begin.append(x)
    begin_s.append(datetime.fromtimestamp(today + x).strftime("%H:%M:%S"))
    x += 300
    end.append(x+1)
    end_s.append(datetime.fromtimestamp(today + x + 1).strftime("%H:%M:%S"))
    begin.append(x)
    begin_s.append(datetime.fromtimestamp(today + x).strftime("%H:%M:%S"))
    x += 300
    end.append(x+1)
    end_s.append(datetime.fromtimestamp(today + x + 1).strftime("%H:%M:%S"))
    begin.append(x)
    begin_s.append(datetime.fromtimestamp(today + x).strftime("%H:%M:%S"))
    x += 300
    end.append(x+1)
    end_s.append(datetime.fromtimestamp(today + x + 1).strftime("%H:%M:%S"))
    begin.append(x)
    begin_s.append(datetime.fromtimestamp(today + x).strftime("%H:%M:%S"))
    x += 300
    end.append(x+1)
    end_s.append(datetime.fromtimestamp(today + x + 1).strftime("%H:%M:%S"))
    begin.append(x)
    begin_s.append(datetime.fromtimestamp(today + x).strftime("%H:%M:%S"))
    x += 300
    end.append(x+1)
    end_s.append(datetime.fromtimestamp(today + x + 1).strftime("%H:%M:%S"))
pd.DataFrame({0:entry,1:stream,2:begin,3:end}).to_csv("shiki.txt",sep=" ",index=None,header=None)
pd.DataFrame({0:entry,1:stream,2:begin_s,3:end_s}).to_csv("shiki_with_time.txt",sep=" ",index=None,header=None)

# %%
entry
# Out:
# ['./movie/keichitsu.mp4',
#  './movie/shunbun.mp4',
#  './movie/seimei.mp4',
#  './movie/kokuu.mp4',
#  './movie/rikka.mp4',
#  './movie/keichitsu.mp4',
#  './movie/shunbun.mp4',
#  './movie/seimei.mp4',
#  './movie/kokuu.mp4',
#  './movie/rikka.mp4',
#  './movie/keichitsu.mp4',
#  './movie/shunbun.mp4',
#  './movie/seimei.mp4',
#  './movie/kokuu.mp4',
#  './movie/rikka.mp4',
#  './movie/keichitsu.mp4',
#  './movie/shunbun.mp4',
#  './movie/seimei.mp4',
#  './movie/kokuu.mp4',
#  './movie/rikka.mp4',
#  './movie/keichitsu.mp4',
#  './movie/shunbun.mp4',
#  './movie/seimei.mp4',
#  './movie/kokuu.mp4',
#  './movie/rikka.mp4',
#  './movie/keichitsu.mp4',
#  './movie/shunbun.mp4',
#  './movie/seimei.mp4',
#  './movie/kokuu.mp4',
#  './movie/rikka.mp4',
#  './movie/keichitsu.mp4',
#  './movie/shunbun.mp4',
#  './movie/seimei.mp4',
#  './movie/kokuu.mp4',
#  './movie/rikka.mp4',
#  './movie/keichitsu.mp4',
#  './movie/shunbun.mp4',
#  './movie/seimei.mp4',
#  './movie/kokuu.mp4',
# ...
